# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size #floor division (integer division)
    print("segment = {}".format(segment))
    # so, is segment the number of total batches that fits into the data text?
    self._cursor = [ offset * segment for offset in range(batch_size)]
    # there are batch_size cursor positions, but separated segment positions between them? Why?? Because it is large enough?
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    # vocabulary is abecedary
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
        # batch as one hot encoding
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  # dimensions of input = probabilities.shape[0] (which actually is batch_size) X vocabulary_size 
  # dimensions of output = probabilities.shape[0] (which actually is batch_size)
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0] # batch_size
  for b in batches: # a list of length = _num_unrollings + 1 (the exta one is the last batch from previous generation)
    s = [''.join(x) for x in zip(s, characters(b))]
    # so s is a list of batch_size string elements of length _num_unrollings + 1
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

one_batch = batches2string(train_batches.next())
print("{}\n --> len={}".format(one_batch, len(one_batch)))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# segment = 1562484
# segment = 1000
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
#  --> len=64
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  # which values can labels have? # labels will be inputs shifted by one time step.
  # labels size is batch_size x vocabulary_size
  #print("log_labels.shape {}".format(labels.shape))
  #print("log_predictions.shape {}".format(predictions.shape))
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  # what is prediction size? 1 x vocabulary_size
  # python slicing: prediction[0] select first dimension from a (1,27) array, resulting in (27,)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64 # needs to be equal to batch_size?
flag_singlemult = True

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  # ix ~ U, input weights [v, n], and input_size is 
  # im ~ W, recurrent weights [n, n]
  # ib ~ b, biases [1, n] ¿Does it  match with U and W during running?
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the simplified cell computation (see Problem 1 below)
  # Simplify the expression by using a single matrix multiply for each, 
  #  and variables that are 4 times larger.
  def lstm_cell_singlemult(i, o, state):
    # i: input [b, v]
    # o: output of previous cell [n, n]
    # Pack weights into a single variable that is 4 times larger
    inp_weights = tf.concat([ix, fx, ox, cx], 1)
    out_weights = tf.concat([im, fm, om, cm], 1)
    # perform simple mult
    single_mult = tf.matmul(i, inp_weights) + tf.matmul(o, out_weights)
    # select appropriate result for each gate
    input_gate = tf.sigmoid(single_mult[:,:num_nodes] + ib)
    forget_gate = tf.sigmoid(single_mult[:,1*num_nodes:2*num_nodes] + fb)
    output_gate = tf.sigmoid(single_mult[:,2*num_nodes:3*num_nodes] + ob)
    update = single_mult[:,3*num_nodes:] + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    return output_gate * tf.tanh(state), state

  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    # i: input [b, v]
    # o: output of previous cell [n, n]
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    # ( [b, v] * [v, n] + [b, n] * [n, n] ) + [1, n] --> biases have to be applied to every row
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings] #  get from 0 to num_unrollings-1, leave last one out
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    if not flag_singlemult:
        output, state = lstm_cell(i, output, state)
    else:
        output, state = lstm_cell_singlemult(i, output, state)
    print("output.shape = {}".format(output.shape))
    outputs.append(output)
  print("outputs_len = {}".format(len(outputs)))

  # State saving across unrollings, and also throughout steps?
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    # output.concat [b*unrollings,n]
    # w [n,v]
    # b [v]
    print("outputs shape = {}".format(tf.concat(outputs, 0).shape))
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    # labels.concat [b*unrollings,v]
    # logits [n*unrollings,v] (b=n)
    print("logits shape = {}".format(logits.shape))
    print("labels shape = {}".format(tf.concat(train_labels, 0).shape))
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  # needed to clip gradients
  # In previous assignments we used minimize(). This method simply combines calls 
  # compute_gradients() and apply_gradients(). If you want to process the gradient before 
  # applying them call compute_gradients() and apply_gradients() explicitly 
  # instead of using the minimize() function.
  # 
  # zip() in conjunction with the * operator can be used to unzip a list:
  gradients, v = zip(*optimizer.compute_gradients(loss))
  # need the list of (gradient, variable) pairs unzipped in order to process the gradients only
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  # tf.group: Create an op that groups multiple operations. When this op finishes, all 
  # ops in inputs have finished. This op has no output.
  reset_sample_state = tf.group(saved_sample_output.assign(tf.zeros([1, num_nodes])),
                                saved_sample_state.assign(tf.zeros([1, num_nodes])))
  if not flag_singlemult:
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
  else:
    sample_output, sample_state = lstm_cell_singlemult(sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# output.shape = (64, 64)
# outputs_len = 10
# outputs shape = (640, 64)
# logits shape = (640, 27)
# labels shape = (640, 27)

# %%
num_steps = 7001
summary_frequency = 100

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
with tf.Session(graph=graph, config=config) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0

  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    
    _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], 
                                        feed_dict=feed_dict)
    mean_loss += l
    
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      # labels size [b*unrollings, v]
      labels = np.concatenate(list(batches)[1:])
      print("labels.shape {}".format(labels.shape))
      print("predictions.shape {}".format(predictions.shape))
      print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
        
      # The perplexity of whatever you're evaluating, on the data you're evaluating it on, 
      # sort of tells you "this thing is right about as often as an x-sided die would be."
      # Computers can predict letters pretty well - a perplexity of about 3.4.
      # - like having a "3.4"-sided die predict each subsequent letter.
    
      if step % (summary_frequency * 10) == 0:
        # Generate some samples, every 10*summary_frequency steps
        print('=' * 80)
        for _ in range(5):
          # sample() returns 1-hot encoded sample
          feed = sample(random_distribution()) # random distr shape is [1, 27]
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            # erickrfonseca in Udacity Forums Feb '16
            # "The original code uses the sample function to allow some variability in the result. 
            # Without it, as you see, it becomes completely deterministic, as the LSTM learned to 
            # score the sequence "of the states" very high."
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            # characters returns a list of a single element since feed is 1x27
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
        
      # Measure validation set perplexity, every summary_frequency steps
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
        
      print('Validation set perplexity: %.2f\n' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.295139 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 26.98
# ================================================================================
#  rycofpxnoslhmslvdvitrlsjlusnedpayadsfsdyiigmkrlif esz txaemllvg biwaoshrtiz asn
# rhee prhhziepixnx afh ppcct npa  ea  hyzr p mpyitfdmyvfleiirtcnhcsc ct  ctenrekm
# iacob tedradwm c mltcjfr nf av zqyqarbinw qbmtglmjx xtcfaforaaqcfq eo yqonmsuh p
# cuw catioeugwil xlyc yxifc watoiuztx   fmk iilwohge ei hcp d knoetrftddzt es eq
# pe gc zafrm ilewhatvetcxgumktg rrlhk  n chnel zun cjtx exctcrsu   rtdkoo ohremgk
# ================================================================================
# Validation set perplexity: 20.16
#
# Average loss at step 100: 2.594371 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 10.89
# Validation set perplexity: 10.34
#
# Average loss at step 200: 2.247871 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 8.77
# Validation set perplexity: 8.64
#
# Average loss at step 300: 2.095217 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 7.32
# Validation set perplexity: 7.98
#
# Average loss at step 400: 1.996551 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 7.57
# Validation set perplexity: 7.68
#
# Average loss at step 500: 1.936571 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 6.57
# Validation set perplexity: 7.17
#
# Average loss at step 600: 1.911401 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 6.19
# Validation set perplexity: 6.92
#
# Average loss at step 700: 1.865252 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.75
#
# Average loss at step 800: 1.826187 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.89
# Validation set perplexity: 6.52
#
# Average loss at step 900: 1.832347 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 7.00
# Validation set perplexity: 6.44
#
# Average loss at step 1000: 1.828002 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.75
# ================================================================================
# ternation mive it of posely sevies midibe s schien whoone surver in the a geagle
# ges one seven stre cover of the a sticlion of qudir i oberat therlisted one two
# rolrs of euretak of the elryy cively worso be actich decevelations goricl grom s
# all nots and the metening infrepol as caxefity one five recane were histo lhoven
# y of the greater of or from thelrcmation a trader nornad of govern merouct will
# ================================================================================
# Validation set perplexity: 6.30
#
# Average loss at step 1100: 1.781626 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.95
#
# Average loss at step 1200: 1.757363 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.99
# Validation set perplexity: 5.68
#
# Average loss at step 1300: 1.737471 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.82
# Validation set perplexity: 5.78
#
# Average loss at step 1400: 1.750726 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.80
# Validation set perplexity: 5.58
#
# Average loss at step 1500: 1.736889 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.86
# Validation set perplexity: 5.48
#
# Average loss at step 1600: 1.745945 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.54
# Validation set perplexity: 5.51
#
# Average loss at step 1700: 1.715094 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.74
# Validation set perplexity: 5.47
#
# Average loss at step 1800: 1.678067 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.30
#
# Average loss at step 1900: 1.653427 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.30
# Validation set perplexity: 5.36
#
# Average loss at step 2000: 1.704123 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.84
# ================================================================================
# ing a revidaly of agailse astrong as nabss in artter on to stawn as manan jo vic
#  s uschemsey list as ito aperianactol was sut the duraubs s im of arctarts an it
# fances gopu popural nive stangalian brong a directors churct arrinstape showal a
# s spited controlsm haots now worlding original india was fours of scho phallic g
# fal bality with manarosshorsses atlestive the wead of the now thoseous commancum
# ================================================================================
# Validation set perplexity: 5.15
#
# Average loss at step 2100: 1.688448 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.91
#
# Average loss at step 2200: 1.688151 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 6.26
# Validation set perplexity: 4.99
#
# Average loss at step 2300: 1.642623 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.92
#
# Average loss at step 2400: 1.667047 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.82
#
# Average loss at step 2500: 1.681711 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.70
#
# Average loss at step 2600: 1.658981 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.76
# Validation set perplexity: 4.62
#
# Average loss at step 2700: 1.663663 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.65
#
# Average loss at step 2800: 1.653477 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.63
# Validation set perplexity: 4.65
#
# Average loss at step 2900: 1.657154 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.72
# Validation set perplexity: 4.73
#
# Average loss at step 3000: 1.655332 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.23
# ================================================================================
# ts left can incan smortal classiected dieic in theore fally partiorisaliam handc
# s eight zero zero zero zero getanto earles and pumbinan the of mave full saftall
# gench ith movakito the related by skonleas tho consiendentional varge betsogied
# foy s was jelacale to deeder toorrionaly which was systed and auglap its easters
# halsed signed tepred lurds freement in as the autice lick is american knat part
# ================================================================================
# Validation set perplexity: 4.68
#
# Average loss at step 3100: 1.634030 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 6.00
# Validation set perplexity: 4.73
#
# Average loss at step 3200: 1.652319 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.63
#
# Average loss at step 3300: 1.639063 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.57
#
# Average loss at step 3400: 1.673479 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.62
#
# Average loss at step 3500: 1.659265 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.66
#
# Average loss at step 3600: 1.665281 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.37
# Validation set perplexity: 4.49
#
# Average loss at step 3700: 1.647966 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.46
#
# Average loss at step 3800: 1.648376 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.61
#
# Average loss at step 3900: 1.637279 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.62
#
# Average loss at step 4000: 1.657937 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.76
# ================================================================================
# ley in carled bycatee the and resormale of bilarious perfication of aza since el
# bers ires on these empire s the penckeripate was or ishiphor governed to bamisti
# ver dejectide americust of attack ilguns hoor as in proe objerbahbolp the endirc
# andicized prodncificisists the twotzer month the nodeciphess and earnotiol rcals
# c people companimment counts it astend its orligime severated orier over recame
# ================================================================================
# Validation set perplexity: 4.80
#
# Average loss at step 4100: 1.635510 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.76
#
# Average loss at step 4200: 1.637941 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.56
#
# Average loss at step 4300: 1.618618 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.60
#
# Average loss at step 4400: 1.617054 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.45
#
# Average loss at step 4500: 1.620574 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.67
#
# Average loss at step 4600: 1.617705 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.71
#
# Average loss at step 4700: 1.630377 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.53
#
# Average loss at step 4800: 1.629582 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.55
#
# Average loss at step 4900: 1.636886 learning rate: 10.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.71
#
# Average loss at step 5000: 1.608888 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.43
# ================================================================================
#  gleced one zero re somide roulp is the raim penchism egim is for by for the gop
# dered two zero zero zero zerost three yout not one him of islavion univers activ
# ny bytensothe is a popularmesed oftr of shasigar and howes symenal soude one nin
# hall manimentice comitating pitchoat desogitis acy so relimmer and build one nin
# y searoning same easly cainnes were simulary world a n behable one nine the five
# ================================================================================
# Validation set perplexity: 4.62
#
# Average loss at step 5100: 1.608388 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.46
#
# Average loss at step 5200: 1.596848 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.40
#
# Average loss at step 5300: 1.580014 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.40
#
# Average loss at step 5400: 1.579891 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.34
#
# Average loss at step 5500: 1.567923 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.34
#
# Average loss at step 5600: 1.583683 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.33
#
# Average loss at step 5700: 1.569659 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.36
#
# Average loss at step 5800: 1.579376 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.37
#
# Average loss at step 5900: 1.576204 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.34
#
# Average loss at step 6000: 1.545882 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.96
# ================================================================================
# garding tometibe following two rolloy this necch was the new hodery tamian in en
# er see priton extinuted sided and fore appcis sace with quirior grouts karlist p
# y agaid care acconsian was some centery and no all of the namor grifaty with a c
# penting believed also criber british odad betwenner builtings head tepplement th
# ual hole basawi in the cath presensity there importane rover generals large the
# ================================================================================
# Validation set perplexity: 4.36
#
# Average loss at step 6100: 1.570520 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.35
#
# Average loss at step 6200: 1.538772 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.36
#
# Average loss at step 6300: 1.548690 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.35
#
# Average loss at step 6400: 1.544495 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.34
#
# Average loss at step 6500: 1.562064 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.34
#
# Average loss at step 6600: 1.600407 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.33
#
# Average loss at step 6700: 1.583817 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.34
#
# Average loss at step 6800: 1.607320 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.33
#
# Average loss at step 6900: 1.587861 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.38
#
# Average loss at step 7000: 1.578617 learning rate: 1.000000
# labels.shape (640, 27)
# predictions.shape (640, 27)
# Minibatch perplexity: 5.06
# ================================================================================
# rele sports surved pagon the and live indursic of nicring of his art uslum memai
# jor weekea the tory of enives and pidkeles kamid and complection of perfusigne o
# ratholism could amereas anal nuvikit of blay a cerristed three the motackss one
# procaric of ndegreed attaiding moses the were destitlies worl is electrous of mo
# ricul imacionare proplical scolaring cressically islateles coul nider doon feeld
# ================================================================================
# Validation set perplexity: 4.38

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# > **Note:** Problem 1 was addressed in one of the the above Jupyter cells; the one in which `tf.Graph()` is constructed and LSTM cell operations are defined.

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
